# %% [markdown]
# # Initial Data Exploration

# %%
import pandas as pd
import geopandas
from shapely.geometry import Point
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from tqdm.auto import tqdm
import numpy as np
import warnings
import math
import re

warnings.filterwarnings("ignore")
tqdm.pandas()

# %load_ext autoreload
# %autoreload 2

# %run ../src/utils.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#  21%|███████████████▍                                                        | 218516/1017199 [03:41<14:13, 936.09it/s]

# %%
train = pd.read_csv('../data/raw/data_train.zip', index_col='Unnamed: 0')
train.shape
# Out:
# (814262, 11)

# %%
test = pd.read_csv('../data/raw/data_test.zip', index_col='Unnamed: 0')
test.shape
# Out:
# (202937, 11)

# %%
data = pd.concat([train, test], axis=0)

# %%
data.tail(5)
# Out:
#                                        hash  \
# 202932  fff9552047b095e8242b4913f3289a26_25
# 202933  fff9552047b095e8242b4913f3289a26_25
# 202934  fff9552047b095e8242b4913f3289a26_25
# 202935  fff9552047b095e8242b4913f3289a26_25
# 202936  fff9552047b095e8242b4913f3289a26_25
#
#                                      trajectory_id time_entry time_exit  vmax  \
# 202932  traj_fff9552047b095e8242b4913f3289a26_25_3   11:23:33  11:23:33   NaN
# 202933  traj_fff9552047b095e8242b4913f3289a26_25_4   12:12:10  12:12:10   NaN
# 202934  traj_fff9552047b095e8242b4913f3289a26_25_5   13:08:14  13:12:01   NaN
# 202935  traj_fff9552047b095e8242b4913f3289a26_25_6   14:14:36  14:14:36   NaN
# 202936  traj_fff9552047b095e8242b4913f3289a26_25_7   15:30:54  15:30:54   NaN
#
#         vmin  vmean       x_entry       y_entry        x_exit        y_exit
# 202932   NaN    NaN  3.762713e+06 -1.935493e+07  3.762713e+06 -1.935493e+07
# 202933   NaN    NaN  3.761040e+06 -1.935274e+07  3.761040e+06 -1.935274e+07
# 202934   NaN    NaN  3.762680e+06 -1.935570e+07  3.762683e+06 -1.935529e+07
# 202935   NaN    NaN  3.761776e+06 -1.935772e+07  3.761776e+06 -1.935772e+07
# 202936   NaN    NaN  3.762713e+06 -1.935478e+07           NaN           NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017199 entries, 0 to 202936
# Data columns (total 11 columns):
# hash             1017199 non-null object
# trajectory_id    1017199 non-null object
# time_entry       1017199 non-null object
# time_exit        1017199 non-null object
# vmax             311474 non-null float64
# vmin             311474 non-null float64
# vmean            328137 non-null float64
# x_entry          1017199 non-null float64
# y_entry          1017199 non-null float64
# x_exit           983684 non-null float64
# y_exit           983684 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 93.1+ MB

# %% [markdown]
# Let's begin by visualizating a simple path taken from one ID in one day.

# %% [markdown]
# As we can see, we have coordinates for an entry and an exit point, where the trajectory happened. We can then calculate the distance that his trajectory took by calculating the euclidian distance between these two points. Let's do that.

# %%
def euclidian_distance(x_one, y_one, x_two, y_two):
    return np.sqrt(np.power((x_one-x_two), 2) + np.power((y_one-y_two), 2))

def minkowski_distance(x_one, y_one, x_two, y_two):
    return abs(x_one-x_two) + abs(y_one-y_two)

data['euclidian_distance'] = np.sqrt(np.power(data.x_entry.values-data.x_exit.values, 2)+np.power(data.y_entry.values-data.y_exit.values, 2))

data['minkowski_distance'] = np.abs(data.x_entry.values-data.x_exit.values) + np.abs(data.y_entry.values-data.y_exit.values)

# %% [markdown]
# Let's explore a little bit about this new variable, beginning by grouping it according wit the hash variable, that indicates one-day trajectory.

# %%
# transforming time variable to timedelta format in pandas
data['minute_entry'] = data.time_entry.progress_apply(lambda x: int(x.split(':')[1]))
data['minute_exit'] = data.time_exit.progress_apply(lambda x: int(x.split(':')[1]))

data['hour_entry'] = data.time_entry.progress_apply(lambda x: int(x.split(':')[0]))
data['hour_exit'] = data.time_exit.progress_apply(lambda x: int(x.split(':')[0]))

data['time_entry'] = pd.to_timedelta(data.time_entry)
data['time_exit'] = pd.to_timedelta(data.time_exit)

# %%
data.head(10)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
# 4  0000a8602cf2def930488dee7cdad104_1
# 5  0000a8602cf2def930488dee7cdad104_1
# 6  0000cf177130469eeac79f67b6bcf3df_9
# 7  0000cf177130469eeac79f67b6bcf3df_9
# 8  0000cf177130469eeac79f67b6bcf3df_9
# 9  0000cf177130469eeac79f67b6bcf3df_9
#
#                                trajectory_id time_entry time_exit      vmax  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32       NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42       NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25       NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23       NaN
# 4  traj_0000a8602cf2def930488dee7cdad104_1_4   14:38:09  14:38:09       NaN
# 5  traj_0000a8602cf2def930488dee7cdad104_1_5   15:02:31  15:18:33       NaN
# 6  traj_0000cf177130469eeac79f67b6bcf3df_9_0   14:29:23  14:29:23  0.000000
# 7  traj_0000cf177130469eeac79f67b6bcf3df_9_1   14:39:49  14:39:49  0.000000
# 8  traj_0000cf177130469eeac79f67b6bcf3df_9_2   14:50:14  14:50:14  0.507809
# 9  traj_0000cf177130469eeac79f67b6bcf3df_9_3   15:00:32  15:29:48  1.149404
#
#        vmin     vmean       x_entry       y_entry        x_exit        y_exit  \
# 0       NaN       NaN  3.751014e+06 -1.909398e+07  3.750326e+06 -1.913634e+07
# 1       NaN       NaN  3.743937e+06 -1.932247e+07  3.744975e+06 -1.931966e+07
# 2       NaN       NaN  3.744868e+06 -1.929356e+07  3.744816e+06 -1.929284e+07
# 3       NaN       NaN  3.744880e+06 -1.929229e+07  3.744809e+06 -1.929049e+07
# 4       NaN       NaN  3.744909e+06 -1.928558e+07  3.744909e+06 -1.928558e+07
# 5       NaN       NaN  3.744945e+06 -1.928183e+07  3.744785e+06 -1.928148e+07
# 6  0.000000  0.000000  3.749450e+06 -1.926506e+07  3.749450e+06 -1.926506e+07
# 7  0.000000  0.000000  3.749090e+06 -1.926726e+07  3.749090e+06 -1.926726e+07
# 8  0.507809  0.507809  3.749042e+06 -1.926632e+07  3.749042e+06 -1.926632e+07
# 9  1.149404  1.149404  3.749088e+06 -1.926605e+07  3.749610e+06 -1.926594e+07
#
#    euclidian_distance  minkowski_distance  minute_entry  minute_exit  \
# 0        42364.863118        43047.231426             4            8
# 1         2989.643628         3841.346373            20           25
# 2          725.658561          776.090116            53            3
# 3         1804.576849         1874.414413            17           37
# 4            0.000000            0.000000            38           38
# 5          389.513093          514.686506             2           18
# 6            0.000000            0.000000            29           29
# 7            0.000000            0.000000            39           39
# 8            0.000000            0.000000            50           50
# 9          534.474570          636.485772             0           29
#
#    hour_entry  hour_exit
# 0           7          7
# 1           7          7
# 2           7          8
# 3           8          8
# 4          14         14
# 5          15         15
# 6          14         14
# 7          14         14
# 8          14         14
# 9          15         15

# %% [markdown]
# The plot above shows the average distance traveled during the day for entry_time and exit_time. As expected, they are correlated and shifted because they represent the same value for exactly the same time.
#
# An interesting point here is how we have two peaks: one approximately during 6 AM and another after lunch time, let's here the exact times.

# %%
x_center = 3750901.5068 + ((3770901.5068-3750901.5068)/2)
y_center = -19268905.6133 + ((-19208905.6133+19268905.6133)/2)

# %%
center = {
    'x_min': 3750901.5068, 'y_min': -19268905.6133,
    'x_max': 3770901.5068, 'y_max': -19208905.6133
}

# %%
def is_inside_city(x, y):
    if (3750901.5068 <= x <= 3770901.5068) and (-19268905.6133 <= y <= -19208905.6133):
        return 1
    else:
        return 0

data['is_inside_city_entry'] = [is_inside_city(x, y) for x, y in zip(data.x_entry, data.y_entry)]
data['is_inside_city_exit'] = [is_inside_city(x, y) for x, y in zip(data.x_exit, data.y_exit)]

# %%
def quadrant(x, y, which):
    if which == 'third':
        if center['x_min'] <= x <= x_center and center['y_min'] <= y <= y_center:
            return 1
        else:
            return 0
        
    elif which == 'first':
        if center['x_min'] <= x <= x_center and center['y_max'] >= y >= y_center:
            return 1
        else:
            return 0
        
    elif which == 'fourth':
        if center['x_max'] >= x >= x_center and center['y_min'] >= y >= y_center:
            return 1
        else:
            return 0
    elif which == 'second':
        if center['x_max'] >= x >= x_center and center['y_min'] <= y <= y_center:
            return 1
        else:
            return 0
    else:
        return 0
        

data['first_quadrant_entry'] = [quadrant(x, y, which='first') for x, y in zip(data.x_entry, data.y_entry)]
data['third_quadrant_entry'] = [quadrant(x, y, which='third') for x, y in zip(data.x_entry, data.y_entry)]
data['fourth_quadrant_entry'] = [quadrant(x, y, which='fourth') for x, y in zip(data.x_entry, data.y_entry)]
data['second_quadrant_entry'] = [quadrant(x, y, which='second') for x, y in zip(data.x_entry, data.y_entry)]

# %% [markdown]
# Again, let's explore this variable temporally.

# %%
# time passed between blind spots
data['time_delta_blind'] = (data.time_entry - data.time_exit.shift(1)) / np.timedelta64(1, 'm')
data.head(3)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...  minute_exit  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...            8
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...           25
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...            3
#
#    hour_entry  hour_exit  is_inside_city_entry  is_inside_city_exit  \
# 0           7          7                     0                    0
# 1           7          7                     0                    0
# 2           7          8                     0                    0
#
#    first_quadrant_entry  third_quadrant_entry  fourth_quadrant_entry  \
# 0                     0                     0                      0
# 1                     0                     0                      0
# 2                     0                     0                      0
#
#    second_quadrant_entry  time_delta_blind
# 0                      0               NaN
# 1                      0         12.033333
# 2                      0         27.833333
#
# [3 rows x 24 columns]

# %%
# time passed between blind spots

data['x_delta_blind'] = data.x_entry - data.x_exit.shift(1)
data['y_delta_blind'] = data.y_entry - data.y_exit.shift(1)

data['distance_blind'] = ((data.x_delta_blind**2) + (data.y_delta_blind)**2)**(1/2)

data.head(4)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...  is_inside_city_entry  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...                     0
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...                     0
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...                     0
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...                     0
#
#    is_inside_city_exit  first_quadrant_entry  third_quadrant_entry  \
# 0                    0                     0                     0
# 1                    0                     0                     0
# 2                    0                     0                     0
# 3                    0                     0                     0
#
#    fourth_quadrant_entry  second_quadrant_entry  time_delta_blind  \
# 0                      0                      0               NaN
# 1                      0                      0         12.033333
# 2                      0                      0         27.833333
# 3                      0                      0         14.416667
#
#    x_delta_blind  y_delta_blind  distance_blind
# 0            NaN            NaN             NaN
# 1   -6388.625577 -186127.626359   186237.235350
# 2    -106.866711   26098.775095    26098.993888
# 3      64.565305     551.388913      555.156205
#
# [4 rows x 27 columns]

# %%
data['trajectory_number'] = data.trajectory_id.progress_apply(lambda x: int(re.findall('_\d+$', x)[0].strip('_')))

data.loc[data.trajectory_number==0, 'distance_blind'] = 0
data.loc[data.trajectory_number==0, 'time_delta_blind'] = 0

# %% [markdown]
# Let's compute angle variation between entries w.r.t the vertexes and center of the city center.

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# Let's begin by extracting some features from the data set. First, let's calculate the distance from each entry_point and exit_point to the center.

# %%
data['distance_cc_entry'] = np.sqrt(((data.x_entry.values-x_center)**2) + ((data.y_entry.values-y_center)**2))
data['distance_cc_exit'] = np.sqrt(((data.x_exit.values-x_center)**2) + ((data.y_exit.values-y_center)**2))

data['diff_cc_exit_entry'] = data.distance_cc_exit - data.distance_cc_entry

# %%
data['time_entry'] = pd.to_timedelta(data.time_entry)
data['time_exit'] = pd.to_timedelta(data.time_exit)

data['deltat_min'] = (data.time_exit - data.time_entry) / np.timedelta64(1, 'm')

# %%
data['x_diff_entry'] = data.x_entry.values-x_center
data['x_diff_exit'] = data.x_exit.values-x_center

data['y_diff_entry'] = data.y_entry.values-y_center
data['y_diff_exit'] = data.y_exit.values-y_center

# %%
data['last_x_entry'] = data.groupby('hash').x_entry.shift(1)
data['last_y_entry'] = data.groupby('hash').y_entry.shift(1)

angle_cols = [
    'cc_middle_angle', 'cc_xmin_ymin_angle', 'cc_xmax_ymin_angle', 'cc_xmin_ymax_angle', 'cc_xmax_ymax_angle'
]

# %%
data = data.reindex(columns=data.columns.tolist() + angle_cols)

# %%
data = data.progress_apply(entry_to_center_angles, axis=1)
data.head(8)

# %% [markdown]
# For full trigonometric observation, let's keep track of angles in degrees.

# %%
data[angle_cols] = data[angle_cols] * 180.0 / np.pi
data.head(8)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
# 4  0000a8602cf2def930488dee7cdad104_1
# 5  0000a8602cf2def930488dee7cdad104_1
# 6  0000cf177130469eeac79f67b6bcf3df_9
# 7  0000cf177130469eeac79f67b6bcf3df_9
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
# 4  traj_0000a8602cf2def930488dee7cdad104_1_4   14:38:09  14:38:09   NaN   NaN
# 5  traj_0000a8602cf2def930488dee7cdad104_1_5   15:02:31  15:18:33   NaN   NaN
# 6  traj_0000cf177130469eeac79f67b6bcf3df_9_0   14:29:23  14:29:23   0.0   0.0
# 7  traj_0000cf177130469eeac79f67b6bcf3df_9_1   14:39:49  14:39:49   0.0   0.0
#
#    vmean       x_entry       y_entry        x_exit  ...  cc_middle_angle  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...              NaN
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...         0.099083
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...         0.168105
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...         0.275732
# 4    NaN  3.744909e+06 -1.928558e+07  3.744909e+06  ...         0.287247
# 5    NaN  3.744945e+06 -1.928183e+07  3.744785e+06  ...         0.320574
# 6    0.0  3.749450e+06 -1.926506e+07  3.749450e+06  ...              NaN
# 7    0.0  3.749090e+06 -1.926726e+07  3.749090e+06  ...         0.251342
#
#    cc_xmin_ymin_angle  cc_xmax_ymin_angle  cc_xmin_ymax_angle  \
# 0                 NaN                 NaN                 NaN
# 1            0.030320            0.144168            0.029985
# 2            0.097111            0.434195            0.029062
# 3            0.230365            0.802901            0.061547
# 4            0.247709            0.834411            0.067771
# 5            0.335418            0.990782            0.068495
# 6                 NaN                 NaN                 NaN
# 7            0.521990            1.554627            0.135584
#
#    cc_xmax_ymax_angle  cc_middle_angle_deg  cc_xmin_ymin_angle_deg  \
# 0                 NaN                  NaN                     NaN
# 1            0.202314             5.677016                1.737198
# 2            0.200937             9.631712                5.564023
# 3            0.288731            15.798265               13.198920
# 4            0.298174            16.458013               14.192684
# 5            0.317325            18.367531               19.218049
# 6                 NaN                  NaN                     NaN
# 7            0.203501            14.400810               29.907826
#
#    cc_xmax_ymin_angle_deg  cc_xmin_ymax_angle_deg  cc_xmax_ymax_angle_deg
# 0                     NaN                     NaN                     NaN
# 1                8.260244                1.718000               11.591758
# 2               24.877521                1.665115               11.512826
# 3               46.002824                3.526404               16.543064
# 4               47.808239                3.883013               17.084087
# 5               56.767630                3.924502               18.181359
# 6                     NaN                     NaN                     NaN
# 7               89.073545                7.768369               11.659770
#
# [8 rows x 40 columns]

# %%
directions_entry = []
for x, y in zip(data.x_diff_entry, data.y_diff_entry):
    directions_entry.append(math.atan2(x, y))
    
data['direction_entry'] = directions_entry

# %%
directions_exit = []
for x, y in zip(data.x_diff_exit, data.y_diff_exit):
    directions_exit.append(math.atan2(x, y))
    
data['direction_exit'] = directions_exit

# %%
data.head(4)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...  distance_cc_entry  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...      145261.881023
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...       85266.551966
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...       56962.437581
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...       55736.470981
#
#    distance_cc_exit  diff_cc_exit_entry  deltat_min  x_diff_entry  \
# 0     103109.487931       -42152.393092    4.016667  -9887.737394
# 1      82313.619352        -2952.932615    5.133333 -16964.317424
# 2      56283.231185         -679.206396    9.883333 -16033.686481
# 3      54033.065612        -1703.405368   19.550000 -16021.441337
#
#     x_diff_exit   y_diff_entry    y_diff_exit  direction_entry  direction_exit
# 0 -10575.691847  144924.969304  102565.692331        -0.068121       -0.102748
# 1 -15926.819770  -83561.934028  -80758.085309        -2.941300       -2.946875
# 2 -16086.006642  -54659.310214  -53935.540259        -2.856258       -2.851747
# 3 -16092.685811  -53384.151345  -51580.981406        -2.850029       -2.839174
#
# [4 rows x 50 columns]

# %%
data['diff_cc_exit_entry_direction'] = data.diff_cc_exit_entry.values * data.direction_entry.values
data['diff_cc_exit_exit_direction'] = data.diff_cc_exit_entry.values * data.direction_exit.values

# %%
border_features = ['left_border_dist', 'right_border_dist', 'top_border_dist', 'bot_border_dist']

data['left_border_dist'] = data.progress_apply(lambda row: entry_border_distance(row, border='left_border'), axis=1)
data['right_border_dist'] = data.progress_apply(lambda row: entry_border_distance(row, border='right_border'), axis=1)
data['top_border_dist'] = data.progress_apply(lambda row: entry_border_distance(row, border='top_border'), axis=1)
data['bot_border_dist'] = data.progress_apply(lambda row: entry_border_distance(row, border='bottom_border'), axis=1)

# %%
data.head(4)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...   y_diff_entry  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...  144924.969304
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...  -83561.934028
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...  -54659.310214
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...  -53384.151345
#
#      y_diff_exit  direction_entry  direction_exit  \
# 0  102565.692331        -0.068121       -0.102748
# 1  -80758.085309        -2.941300       -2.946875
# 2  -53935.540259        -2.856258       -2.851747
# 3  -51580.981406        -2.850029       -2.839174
#
#    diff_cc_exit_entry_direction  diff_cc_exit_exit_direction  \
# 0                   2871.464400                  4331.086115
# 1                   8685.460233                  8701.923441
# 2                   1939.988952                  1936.924601
# 3                   4854.755350                  4836.263586
#
#    left_border_dist  right_border_dist  top_border_dist  bot_border_dist
# 0     114925.024135      116633.059928    114924.969304    174924.969304
# 1      54012.799354       59966.283785    113775.281047     54012.799354
# 2      25386.747582       35858.533322     84874.048910     25386.747582
# 3      24146.972686       34984.767305     83601.282594     24146.972686
#
# [4 rows x 56 columns]

# %%
data = data.loc[:,~data.columns.duplicated()]
data.head(4)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...   y_diff_entry  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...  144924.969304
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...  -83561.934028
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...  -54659.310214
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...  -53384.151345
#
#      y_diff_exit  direction_entry  direction_exit  \
# 0  102565.692331        -0.068121       -0.102748
# 1  -80758.085309        -2.941300       -2.946875
# 2  -53935.540259        -2.856258       -2.851747
# 3  -51580.981406        -2.850029       -2.839174
#
#    diff_cc_exit_entry_direction  diff_cc_exit_exit_direction  \
# 0                   2871.464400                  4331.086115
# 1                   8685.460233                  8701.923441
# 2                   1939.988952                  1936.924601
# 3                   4854.755350                  4836.263586
#
#    left_border_dist  right_border_dist  top_border_dist  bot_border_dist
# 0     114925.024135      116633.059928    114924.969304    174924.969304
# 1      54012.799354       59966.283785    113775.281047     54012.799354
# 2      25386.747582       35858.533322     84874.048910     25386.747582
# 3      24146.972686       34984.767305     83601.282594     24146.972686
#
# [4 rows x 56 columns]

# %%
data['vuniform'] = data['euclidian_distance'] / data['deltat_min']

# %% [markdown]
# ### Aggregating features
#
# We can also work with aggregating features. In this way we can measure features representing if a person has taken a lot of paths, velocity, average, sum, distance, etc.

# %%
cols_to_agg = ['left_border_dist', 'right_border_dist', 'top_border_dist', 'bot_border_dist',
               'euclidian_distance', 'minkowski_distance', 'deltat_min', 'distance_cc_entry',
               'distance_cc_exit', 'diff_cc_exit_entry', 'direction_entry', 'direction_exit',
               'is_inside_city_exit', 'diff_cc_exit_entry_direction', 'vuniform',
               'distance_blind', 'time_delta_blind', 'diff_cc_exit_exit_direction',
               'first_quadrant_entry', 'third_quadrant_entry', 'fourth_quadrant_entry', 'second_quadrant_entry'] + angle_cols
window = 5

agg_features = (data.groupby(['hash', 'time_entry', 'trajectory_id'])[cols_to_agg]
                .mean()
                .shift(1)
                .rolling(window, min_periods=1)
                .agg(['mean', 'max', 'std', 'min', 'sum']))

agg_features.columns = ["_".join(x) for x in agg_features.columns.ravel()]
data = data.merge(agg_features.reset_index(), 
                    on=['hash', 'trajectory_id', 'time_entry'])
data.head(4)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...
#
#    cc_xmin_ymax_angle_deg_mean  cc_xmin_ymax_angle_deg_max  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                     1.718000                       1.718
# 3                     1.691557                       1.718
#
#    cc_xmin_ymax_angle_deg_std  cc_xmin_ymax_angle_deg_min  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                    1.718000
# 3                    0.037396                    1.665115
#
#    cc_xmin_ymax_angle_deg_sum  cc_xmax_ymax_angle_deg_mean  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                    1.718000                    11.591758
# 3                    3.383115                    11.552292
#
#    cc_xmax_ymax_angle_deg_max  cc_xmax_ymax_angle_deg_std  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                   11.591758                         NaN
# 3                   11.591758                    0.055813
#
#    cc_xmax_ymax_angle_deg_min  cc_xmax_ymax_angle_deg_sum
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                   11.591758                   11.591758
# 3                   11.512826                   23.104584
#
# [4 rows x 217 columns]

# %% [markdown]
# We can also calculate the number of trajectories taken by an id.

# %%
count_trajectories = (data.groupby(['hash','time_entry', 'trajectory_id'])
                      .trajectory_number.mean()
                      .shift(1)
                      .rolling(5, min_periods=1)
                      .agg(['sum']))
count_trajectories.columns = ["trajectory_"+x for x in count_trajectories.columns.ravel()]
data = data.merge(count_trajectories.reset_index(), 
                    on=['hash', 'trajectory_id', 'time_entry'])
data.head(4)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id time_entry time_exit  vmax  vmin  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32   NaN   NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42   NaN   NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25   NaN   NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23   NaN   NaN
#
#    vmean       x_entry       y_entry        x_exit  ...  \
# 0    NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...
# 1    NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...
# 2    NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...
# 3    NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...
#
#    cc_xmin_ymax_angle_deg_max  cc_xmin_ymax_angle_deg_std  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                       1.718                         NaN
# 3                       1.718                    0.037396
#
#    cc_xmin_ymax_angle_deg_min  cc_xmin_ymax_angle_deg_sum  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                    1.718000                    1.718000
# 3                    1.665115                    3.383115
#
#    cc_xmax_ymax_angle_deg_mean  cc_xmax_ymax_angle_deg_max  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                    11.591758                   11.591758
# 3                    11.552292                   11.591758
#
#    cc_xmax_ymax_angle_deg_std  cc_xmax_ymax_angle_deg_min  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                   11.591758
# 3                    0.055813                   11.512826
#
#    cc_xmax_ymax_angle_deg_sum  trajectory_sum
# 0                         NaN             NaN
# 1                         NaN             0.0
# 2                   11.591758             1.0
# 3                   23.104584             3.0
#
# [4 rows x 218 columns]

# %%
last_features = (data.groupby(['hash', 'time_entry', 'trajectory_id'])[cols_to_agg+['y_exit', 'x_exit']]
                .mean()
                .shift(1))

last_features.columns = ['last_'+x for x in last_features.columns.ravel()]
data = data.merge(last_features.reset_index(), 
                    on=['hash', 'trajectory_id', 'time_entry'])

# %%
data['last_distance'] = data.euclidian_distance.shift(1)

# %%
data['last_exit'] = data.groupby('hash').time_exit.shift(1)
data['last_to_current_timedelta'] = (data['time_entry'] - data['last_exit']) / np.timedelta64(1, 'm')

# %%
data.head(10)
# Out:
#                                  hash  \
# 0  0000a8602cf2def930488dee7cdad104_1
# 1  0000a8602cf2def930488dee7cdad104_1
# 2  0000a8602cf2def930488dee7cdad104_1
# 3  0000a8602cf2def930488dee7cdad104_1
# 4  0000a8602cf2def930488dee7cdad104_1
# 5  0000a8602cf2def930488dee7cdad104_1
# 6  0000cf177130469eeac79f67b6bcf3df_9
# 7  0000cf177130469eeac79f67b6bcf3df_9
# 8  0000cf177130469eeac79f67b6bcf3df_9
# 9  0000cf177130469eeac79f67b6bcf3df_9
#
#                                trajectory_id time_entry time_exit      vmax  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0   07:04:31  07:08:32       NaN
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1   07:20:34  07:25:42       NaN
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2   07:53:32  08:03:25       NaN
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3   08:17:50  08:37:23       NaN
# 4  traj_0000a8602cf2def930488dee7cdad104_1_4   14:38:09  14:38:09       NaN
# 5  traj_0000a8602cf2def930488dee7cdad104_1_5   15:02:31  15:18:33       NaN
# 6  traj_0000cf177130469eeac79f67b6bcf3df_9_0   14:29:23  14:29:23  0.000000
# 7  traj_0000cf177130469eeac79f67b6bcf3df_9_1   14:39:49  14:39:49  0.000000
# 8  traj_0000cf177130469eeac79f67b6bcf3df_9_2   14:50:14  14:50:14  0.507809
# 9  traj_0000cf177130469eeac79f67b6bcf3df_9_3   15:00:32  15:29:48  1.149404
#
#        vmin     vmean       x_entry       y_entry        x_exit  ...  \
# 0       NaN       NaN  3.751014e+06 -1.909398e+07  3.750326e+06  ...
# 1       NaN       NaN  3.743937e+06 -1.932247e+07  3.744975e+06  ...
# 2       NaN       NaN  3.744868e+06 -1.929356e+07  3.744816e+06  ...
# 3       NaN       NaN  3.744880e+06 -1.929229e+07  3.744809e+06  ...
# 4       NaN       NaN  3.744909e+06 -1.928558e+07  3.744909e+06  ...
# 5       NaN       NaN  3.744945e+06 -1.928183e+07  3.744785e+06  ...
# 6  0.000000  0.000000  3.749450e+06 -1.926506e+07  3.749450e+06  ...
# 7  0.000000  0.000000  3.749090e+06 -1.926726e+07  3.749090e+06  ...
# 8  0.507809  0.507809  3.749042e+06 -1.926632e+07  3.749042e+06  ...
# 9  1.149404  1.149404  3.749088e+06 -1.926605e+07  3.749610e+06  ...
#
#    last_cc_middle_angle_deg  last_cc_xmin_ymin_angle_deg  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                  5.677016                     1.737198
# 3                  9.631712                     5.564023
# 4                 15.798265                    13.198920
# 5                 16.458013                    14.192684
# 6                 18.367531                    19.218049
# 7                       NaN                          NaN
# 8                 14.400810                    29.907826
# 9                 25.533317                    44.877034
#
#    last_cc_xmax_ymin_angle_deg  last_cc_xmin_ymax_angle_deg  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                     8.260244                     1.718000
# 3                    24.877521                     1.665115
# 4                    46.002824                     3.526404
# 5                    47.808239                     3.883013
# 6                    56.767630                     3.924502
# 7                          NaN                          NaN
# 8                    89.073545                     7.768369
# 9                    82.772557                     4.698614
#
#    last_cc_xmax_ymax_angle_deg   last_y_exit   last_x_exit  last_distance  \
# 0                          NaN           NaN           NaN            NaN
# 1                          NaN -1.913634e+07  3.750326e+06   42364.863118
# 2                    11.591758 -1.931966e+07  3.744975e+06    2989.643628
# 3                    11.512826 -1.929284e+07  3.744816e+06     725.658561
# 4                    16.543064 -1.929049e+07  3.744809e+06    1804.576849
# 5                    17.084087 -1.928558e+07  3.744909e+06       0.000000
# 6                    18.181359 -1.928148e+07  3.744785e+06     389.513093
# 7                          NaN -1.926506e+07  3.749450e+06       0.000000
# 8                    11.659770 -1.926726e+07  3.749090e+06       0.000000
# 9                    23.414236 -1.926632e+07  3.749042e+06       0.000000
#
#    last_exit  last_to_current_timedelta
# 0        NaT                        NaN
# 1   07:08:32                  12.033333
# 2   07:25:42                  27.833333
# 3   08:03:25                  14.416667
# 4   08:37:23                 360.766667
# 5   14:38:09                  24.366667
# 6        NaT                        NaN
# 7   14:29:23                  10.433333
# 8   14:39:49                  10.416667
# 9   14:50:14                  10.300000
#
# [10 rows x 255 columns]

# %% [markdown]
# ## Training

# %%
three_oclock = pd.to_timedelta('15:00:00')
four_oclock = pd.to_timedelta('16:00:00')

train = data.loc[:814266]
test = data.loc[814262:]

data_train = train[(train.time_exit >= three_oclock) & (train.time_exit <= four_oclock)].copy()

# %%
data_train.shape
# Out:
# (134064, 255)

# %%
data_train.is_inside_city_exit.value_counts(normalize=True)
# Out:
# 0    0.728637
# 1    0.271363
# Name: is_inside_city_exit, dtype: float64

# %%
data_train.columns.tolist()
# Out:
# ['hash',
#  'trajectory_id',
#  'time_entry',
#  'time_exit',
#  'vmax',
#  'vmin',
#  'vmean',
#  'x_entry',
#  'y_entry',
#  'x_exit',
#  'y_exit',
#  'euclidian_distance',
#  'minkowski_distance',
#  'minute_entry',
#  'minute_exit',
#  'hour_entry',
#  'hour_exit',
#  'is_inside_city_entry',
#  'is_inside_city_exit',
#  'first_quadrant_entry',
#  'third_quadrant_entry',
#  'fourth_quadrant_entry',
#  'second_quadrant_entry',
#  'time_delta_blind',
#  'x_delta_blind',
#  'y_delta_blind',
#  'distance_blind',
#  'trajectory_number',
#  'last_x_entry',
#  'last_y_entry',
#  'cc_middle_angle',
#  'cc_xmin_ymin_angle',
#  'cc_xmax_ymin_angle',
#  'cc_xmin_ymax_angle',
#  'cc_xmax_ymax_angle',
#  'cc_middle_angle_deg',
#  'cc_xmin_ymin_angle_deg',
#  'cc_xmax_ymin_angle_deg',
#  'cc_xmin_ymax_angle_deg',
#  'cc_xmax_ymax_angle_deg',
#  'distance_cc_entry',
#  'distance_cc_exit',
#  'diff_cc_exit_entry',
#  'deltat_min',
#  'x_diff_entry',
#  'x_diff_exit',
#  'y_diff_entry',
#  'y_diff_exit',
#  'direction_entry',
#  'direction_exit',
#  'diff_cc_exit_entry_direction',
#  'diff_cc_exit_exit_direction',
#  'left_border_dist',
#  'right_border_dist',
#  'top_border_dist',
#  'bot_border_dist',
#  'vuniform',
#  'left_border_dist_mean',
#  'left_border_dist_max',
#  'left_border_dist_std',
#  'left_border_dist_min',
#  'left_border_dist_sum',
#  'right_border_dist_mean',
#  'right_border_dist_max',
#  'right_border_dist_std',
#  'right_border_dist_min',
#  'right_border_dist_sum',
#  'top_border_dist_mean',
#  'top_border_dist_max',
#  'top_border_dist_std',
#  'top_border_dist_min',
#  'top_border_dist_sum',
#  'bot_border_dist_mean',
#  'bot_border_dist_max',
#  'bot_border_dist_std',
#  'bot_border_dist_min',
#  'bot_border_dist_sum',
#  'euclidian_distance_mean',
#  'euclidian_distance_max',
#  'euclidian_distance_std',
#  'euclidian_distance_min',
#  'euclidian_distance_sum',
#  'minkowski_distance_mean',
#  'minkowski_distance_max',
#  'minkowski_distance_std',
#  'minkowski_distance_min',
#  'minkowski_distance_sum',
#  'deltat_min_mean',
#  'deltat_min_max',
#  'deltat_min_std',
#  'deltat_min_min',
#  'deltat_min_sum',
#  'distance_cc_entry_mean',
#  'distance_cc_entry_max',
#  'distance_cc_entry_std',
#  'distance_cc_entry_min',
#  'distance_cc_entry_sum',
#  'distance_cc_exit_mean',
#  'distance_cc_exit_max',
#  'distance_cc_exit_std',
#  'distance_cc_exit_min',
#  'distance_cc_exit_sum',
#  'diff_cc_exit_entry_mean',
#  'diff_cc_exit_entry_max',
#  'diff_cc_exit_entry_std',
#  'diff_cc_exit_entry_min',
#  'diff_cc_exit_entry_sum',
#  'direction_entry_mean',
#  'direction_entry_max',
#  'direction_entry_std',
#  'direction_entry_min',
#  'direction_entry_sum',
#  'direction_exit_mean',
#  'direction_exit_max',
#  'direction_exit_std',
#  'direction_exit_min',
#  'direction_exit_sum',
#  'is_inside_city_exit_mean',
#  'is_inside_city_exit_max',
#  'is_inside_city_exit_std',
#  'is_inside_city_exit_min',
#  'is_inside_city_exit_sum',
#  'diff_cc_exit_entry_direction_mean',
#  'diff_cc_exit_entry_direction_max',
#  'diff_cc_exit_entry_direction_std',
#  'diff_cc_exit_entry_direction_min',
#  'diff_cc_exit_entry_direction_sum',
#  'vuniform_mean',
#  'vuniform_max',
#  'vuniform_std',
#  'vuniform_min',
#  'vuniform_sum',
#  'distance_blind_mean',
#  'distance_blind_max',
#  'distance_blind_std',
#  'distance_blind_min',
#  'distance_blind_sum',
#  'time_delta_blind_mean',
#  'time_delta_blind_max',
#  'time_delta_blind_std',
#  'time_delta_blind_min',
#  'time_delta_blind_sum',
#  'diff_cc_exit_exit_direction_mean',
#  'diff_cc_exit_exit_direction_max',
#  'diff_cc_exit_exit_direction_std',
#  'diff_cc_exit_exit_direction_min',
#  'diff_cc_exit_exit_direction_sum',
#  'first_quadrant_entry_mean',
#  'first_quadrant_entry_max',
#  'first_quadrant_entry_std',
#  'first_quadrant_entry_min',
#  'first_quadrant_entry_sum',
#  'third_quadrant_entry_mean',
#  'third_quadrant_entry_max',
#  'third_quadrant_entry_std',
#  'third_quadrant_entry_min',
#  'third_quadrant_entry_sum',
#  'fourth_quadrant_entry_mean',
#  'fourth_quadrant_entry_max',
#  'fourth_quadrant_entry_std',
#  'fourth_quadrant_entry_min',
#  'fourth_quadrant_entry_sum',
#  'second_quadrant_entry_mean',
#  'second_quadrant_entry_max',
#  'second_quadrant_entry_std',
#  'second_quadrant_entry_min',
#  'second_quadrant_entry_sum',
#  'cc_middle_angle_mean',
#  'cc_middle_angle_max',
#  'cc_middle_angle_std',
#  'cc_middle_angle_min',
#  'cc_middle_angle_sum',
#  'cc_xmin_ymin_angle_mean',
#  'cc_xmin_ymin_angle_max',
#  'cc_xmin_ymin_angle_std',
#  'cc_xmin_ymin_angle_min',
#  'cc_xmin_ymin_angle_sum',
#  'cc_xmax_ymin_angle_mean',
#  'cc_xmax_ymin_angle_max',
#  'cc_xmax_ymin_angle_std',
#  'cc_xmax_ymin_angle_min',
#  'cc_xmax_ymin_angle_sum',
#  'cc_xmin_ymax_angle_mean',
#  'cc_xmin_ymax_angle_max',
#  'cc_xmin_ymax_angle_std',
#  'cc_xmin_ymax_angle_min',
#  'cc_xmin_ymax_angle_sum',
#  'cc_xmax_ymax_angle_mean',
#  'cc_xmax_ymax_angle_max',
#  'cc_xmax_ymax_angle_std',
#  'cc_xmax_ymax_angle_min',
#  'cc_xmax_ymax_angle_sum',
#  'cc_middle_angle_deg_mean',
#  'cc_middle_angle_deg_max',
#  'cc_middle_angle_deg_std',
#  'cc_middle_angle_deg_min',
#  'cc_middle_angle_deg_sum',
#  'cc_xmin_ymin_angle_deg_mean',
#  'cc_xmin_ymin_angle_deg_max',
#  'cc_xmin_ymin_angle_deg_std',
#  'cc_xmin_ymin_angle_deg_min',
#  'cc_xmin_ymin_angle_deg_sum',
#  'cc_xmax_ymin_angle_deg_mean',
#  'cc_xmax_ymin_angle_deg_max',
#  'cc_xmax_ymin_angle_deg_std',
#  'cc_xmax_ymin_angle_deg_min',
#  'cc_xmax_ymin_angle_deg_sum',
#  'cc_xmin_ymax_angle_deg_mean',
#  'cc_xmin_ymax_angle_deg_max',
#  'cc_xmin_ymax_angle_deg_std',
#  'cc_xmin_ymax_angle_deg_min',
#  'cc_xmin_ymax_angle_deg_sum',
#  'cc_xmax_ymax_angle_deg_mean',
#  'cc_xmax_ymax_angle_deg_max',
#  'cc_xmax_ymax_angle_deg_std',
#  'cc_xmax_ymax_angle_deg_min',
#  'cc_xmax_ymax_angle_deg_sum',
#  'trajectory_sum',
#  'last_left_border_dist',
#  'last_right_border_dist',
#  'last_top_border_dist',
#  'last_bot_border_dist',
#  'last_euclidian_distance',
#  'last_minkowski_distance',
#  'last_deltat_min',
#  'last_distance_cc_entry',
#  'last_distance_cc_exit',
#  'last_diff_cc_exit_entry',
#  'last_direction_entry',
#  'last_direction_exit',
#  'last_is_inside_city_exit',
#  'last_diff_cc_exit_entry_direction',
#  'last_vuniform',
#  'last_distance_blind',
#  'last_time_delta_blind',
#  'last_diff_cc_exit_exit_direction',
#  'last_first_quadrant_entry',
#  'last_third_quadrant_entry',
#  'last_fourth_quadrant_entry',
#  'last_second_quadrant_entry',
#  'last_cc_middle_angle',
#  'last_cc_xmin_ymin_angle',
#  'last_cc_xmax_ymin_angle',
#  'last_cc_xmin_ymax_angle',
#  'last_cc_xmax_ymax_angle',
#  'last_cc_middle_angle_deg',
#  'last_cc_xmin_ymin_angle_deg',
#  'last_cc_xmax_ymin_angle_deg',
#  'last_cc_xmin_ymax_angle_deg',
#  'last_cc_xmax_ymax_angle_deg',
#  'last_y_exit',
#  'last_x_exit',
#  'last_distance',
#  'last_exit',
#  'last_to_current_timedelta']

# %%
feat_eng_angle_cols = [
    'cc_middle_angle_mean',
    'cc_middle_angle_max',
    'cc_middle_angle_std',
    'cc_middle_angle_min',
    'cc_middle_angle_sum',
    'cc_xmin_ymin_angle_mean',
    'cc_xmin_ymin_angle_max',
    'cc_xmin_ymin_angle_std',
    'cc_xmin_ymin_angle_min',
    'cc_xmin_ymin_angle_sum',
    'cc_xmax_ymin_angle_mean',
    'cc_xmax_ymin_angle_max',
    'cc_xmax_ymin_angle_std',
    'cc_xmax_ymin_angle_min',
    'cc_xmax_ymin_angle_sum',
    'cc_xmin_ymax_angle_mean',
    'cc_xmin_ymax_angle_max',
    'cc_xmin_ymax_angle_std',
    'cc_xmin_ymax_angle_min',
    'cc_xmin_ymax_angle_sum',
    'cc_xmax_ymax_angle_mean',
    'cc_xmax_ymax_angle_max',
    'cc_xmax_ymax_angle_std',
    'cc_xmax_ymax_angle_min',
    'cc_xmax_ymax_angle_sum',
    'last_cc_middle_angle',
    'last_cc_xmin_ymin_angle',
    'last_cc_xmax_ymin_angle',
    'last_cc_xmin_ymax_angle',
    'last_cc_xmax_ymax_angle'
]

# %%
data_train = data_train.fillna(value=0)

features = ['vmax',
            'vmin',
            'vmean',
            'x_entry',
            'y_entry',
            'is_inside_city_entry',
            'euclidian_distance_mean',
             'euclidian_distance_max',
             'euclidian_distance_std',
             'euclidian_distance_min',
             'euclidian_distance_sum',
            'deltat_min_mean',
             'deltat_min_max',
             'deltat_min_std',
             'deltat_min_min',
             'deltat_min_sum',
            'distance_cc_entry',
            'deltat_min',
            'last_distance',
            'minute_entry',
            'hour_entry',
            'minute_exit',
            'hour_exit',
            'first_quadrant_entry_mean',
             'first_quadrant_entry_max',
             'first_quadrant_entry_std',
             'first_quadrant_entry_min',
             'first_quadrant_entry_sum',
             'third_quadrant_entry_mean',
             'third_quadrant_entry_max',
             'third_quadrant_entry_std',
             'third_quadrant_entry_min',
             'third_quadrant_entry_sum',
             'fourth_quadrant_entry_mean',
             'fourth_quadrant_entry_max',
             'fourth_quadrant_entry_std',
             'fourth_quadrant_entry_min',
             'fourth_quadrant_entry_sum',
             'second_quadrant_entry_mean',
             'second_quadrant_entry_max',
             'second_quadrant_entry_std',
             'second_quadrant_entry_min',
             'second_quadrant_entry_sum',
              'last_first_quadrant_entry',
             'last_third_quadrant_entry',
             'last_fourth_quadrant_entry',
             'last_second_quadrant_entry', 
           'last_y_exit', 
           'last_x_exit',
           'left_border_dist',
           'right_border_dist',
           'top_border_dist',
           'bot_border_dist',
           'left_border_dist_mean',
           'left_border_dist_max',
           'left_border_dist_std',
           'left_border_dist_min',
           'left_border_dist_sum',
           'right_border_dist_mean',
           'right_border_dist_max',
           'right_border_dist_std',
           'right_border_dist_min',
           'right_border_dist_sum',
           'top_border_dist_mean',
           'top_border_dist_max',
           'top_border_dist_std',
           'top_border_dist_min',
           'top_border_dist_sum',
           'bot_border_dist_mean',
           'bot_border_dist_max',
           'bot_border_dist_std',
           'bot_border_dist_min',
           'bot_border_dist_sum']

target = ['is_inside_city_exit']

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

dt_train, dt_test = train_test_split(data_train, test_size=0.20, random_state=20)
dt_train.shape, dt_test.shape
# Out:
# ((107251, 255), (26813, 255))

# %%
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, r2_score, accuracy_score

pipeline = make_pipeline(LGBMClassifier(n_estimators=150, seed=20))

pipeline.fit(dt_train[features], dt_train[target])
predicted = pipeline.predict(dt_test[features])

f1_score(dt_test[target], predicted)
# Out:
# 0.8822488139913615

# %%
dt_test[target].is_inside_city_exit.value_counts(normalize=True)
# Out:
# 0    0.725693
# 1    0.274307
# Name: is_inside_city_exit, dtype: float64

# %%
f, ax = plt.subplots(figsize=(15, 10))

feat_importances_gb = pd.Series(pipeline.steps[0][1].feature_importances_, index=data_train[features].columns)
feat_importances_gb.nlargest(25).plot(kind='barh', color=cm.rainbow(np.linspace(0, 1, 25)))

# %% [markdown]
# ## Features Set 2

# %%
features += ['last_y_entry', 'last_x_entry', 'trajectory_sum', 'distance_blind_mean', 
            'last_distance_blind', 'last_time_delta_blind']

# %%
pipeline = make_pipeline(LGBMClassifier(n_estimators=150, seed=20))

pipeline.fit(dt_train[features], dt_train[target])
predicted = pipeline.predict(dt_test[features])

f1_score(dt_test[target], predicted)
# Out:
# 0.8833168526628055

# %%
f, ax = plt.subplots(figsize=(15, 10))

feat_importances_gb = pd.Series(pipeline.steps[0][1].feature_importances_, index=data_train[features].columns)
feat_importances_gb.nlargest(25).plot(kind='barh', color=cm.rainbow(np.linspace(0, 1, 25)))

# %% [markdown]
# ## Features Set 3

# %%
list(set(data_train.columns) - set(features))

features += ['distance_cc_entry_mean',
     'last_diff_cc_exit_entry',
     'distance_cc_exit_mean',
     'diff_cc_exit_entry_mean',
     'last_distance_cc_entry',
     'x_diff_entry',
     'last_distance_cc_exit',
     'trajectory_number',
     'last_is_inside_city_exit',
     'x_delta_blind',
     'y_diff_entry',
     'is_inside_city_exit_mean']

pipeline.fit(dt_train[features], dt_train[target])
predicted = pipeline.predict(dt_test[features])

f1_score(dt_test[target], predicted)
# Out:
# 0.8846045197740112

# %%
f, ax = plt.subplots(figsize=(15, 10))

feat_importances_gb = pd.Series(pipeline.steps[0][1].feature_importances_, index=data_train[features].columns)
feat_importances_gb.nlargest(25).plot(kind='barh', color=cm.rainbow(np.linspace(0, 1, 25)))

# %% [markdown]
# ## Feature Set 4

# %%
features += ['time_delta_blind_mean',
         'direction_entry_mean',
         'last_direction_exit',
         'last_diff_cc_exit_entry_direction',
         'time_delta_blind',
         'y_delta_blind',
         'direction_entry',
         'last_direction_entry',
         'last_diff_cc_exit_exit_direction',
         'direction_exit_mean',
         'diff_cc_exit_exit_direction_mean',
         'distance_blind']

pipeline.fit(dt_train[features], dt_train[target])
predicted = pipeline.predict(dt_test[features])

f1_score(dt_test[target], predicted)
# Out:
# 0.8840722959615929

# %%
f, ax = plt.subplots(figsize=(15, 10))

feat_importances_gb = pd.Series(pipeline.steps[0][1].feature_importances_, index=data_train[features].columns)
feat_importances_gb.nlargest(25).plot(kind='barh', color=cm.rainbow(np.linspace(0, 1, 25)))

# %% [markdown]
# ## Feature Set 5

# %%
list(set(data_train.columns) - set(features))

features += [
         'direction_entry_min',
         'direction_exit_sum',
         'distance_blind_sum',
         'diff_cc_exit_entry_direction_min',
         'time_delta_blind_std',
         'time_delta_blind_min',
         'diff_cc_exit_exit_direction_max',
         'minkowski_distance_mean',
         'last_minkowski_distance',
         'distance_cc_exit_std',
         'diff_cc_exit_entry_sum',
         'distance_cc_exit_sum',
         'direction_exit_min',
         'minkowski_distance_max',
         'direction_exit_std',
         'time_delta_blind_max',
         'diff_cc_exit_entry_min',
         'distance_cc_entry_std',
         'distance_cc_exit_min',
         'direction_entry_std',
         'direction_exit_max',
         'diff_cc_exit_entry_direction_max',
         'is_inside_city_exit_min',
         'distance_cc_entry_max',
         'diff_cc_exit_exit_direction_std',
         'is_inside_city_exit_max',
         'direction_entry_sum',
         'minkowski_distance_std',
         'diff_cc_exit_entry_direction_mean',
         'distance_cc_exit_max',
         'distance_blind_min',
         'is_inside_city_exit_sum',
         'minkowski_distance_sum',
         'diff_cc_exit_exit_direction_min',
         'diff_cc_exit_exit_direction_sum',
         'direction_entry_max',
         'minkowski_distance_min',
         'distance_cc_entry_sum',
         'diff_cc_exit_entry_direction_sum',
         'diff_cc_exit_entry_max',
         'is_inside_city_exit_std',
         'distance_blind_max',
         'distance_cc_entry_min',
         'time_delta_blind_sum',
         'diff_cc_exit_entry_direction_std',
         'distance_blind_std',
         'diff_cc_exit_entry_std'] + feat_eng_angle_cols

pipeline.fit(dt_train[features], dt_train[target])
predicted = pipeline.predict(dt_test[features])

f1_score(dt_test[target], predicted)
# Out:
# 0.8838065566805919

# %%
f, ax = plt.subplots(figsize=(15, 10))

feat_importances_gb = pd.Series(pipeline.steps[0][1].feature_importances_, index=data_train[features].columns)
feat_importances_gb.nlargest(25).plot(kind='barh', color=cm.rainbow(np.linspace(0, 1, 25)))

# %%
gridParams = {
    'learning_rate': [0.1, 0.2, 0.3],
    'n_estimators': [150],
    'num_leaves': [24, 45], # large num_leaves helps improve accuracy but might lead to over-fitting
    'boosting_type' : ['gbdt', 'dart'], # for better accuracy -> try dart
    'objective' : ['regression_l2'],
    'max_depth': [5],
    'max_bin':[255], # large max_bin helps improve accuracy but might slow down training progress
    'random_state' : [20],
    'bagging_fraction': [1.0, 0.8],
    'bagging_freq': [0, 30, 50],
    'subsample' : [0.7, 0.75],
    'reg_alpha' : [1, 1.2],
    'reg_lambda' : [1, 1.2, 1.4]
}

# %%
from sklearn.model_selection import GridSearchCV

model = LGBMClassifier(n_estimators=150, seed=20)
grid = GridSearchCV(model, gridParams, verbose=1, cv=4, n_jobs=-1)
grid.fit(dt_train[features], dt_train[target])

print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 4 folds for each of 864 candidates, totalling 3456 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 84.1min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 135.3min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 195.6min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 263.3min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 339.7min
# [Parallel(n_jobs=-1)]: Done 3456 out of 3456 | elapsed: 372.2min finished
# {'bagging_fraction': 1.0, 'bagging_freq': 0, 'boosting_type': 'dart', 'learning_rate': 0.3, 'max_bin': 255, 'max_depth': 5, 'n_estimators': 150, 'num_leaves': 24, 'objective': 'regression_l2', 'random_state': 20, 'reg_alpha': 1, 'reg_lambda': 1.4, 'subsample': 0.7}
# 0.9392359977995544

# %%
params = {
    'task': 'train',
#     'feature_fraction': 0.9
}
# params = {}
for key in grid.best_params_:
    params[key] = grid.best_params_[key]
params
# Out:
# {'task': 'train',
#  'bagging_fraction': 1.0,
#  'bagging_freq': 0,
#  'boosting_type': 'dart',
#  'learning_rate': 0.3,
#  'max_bin': 255,
#  'max_depth': 5,
#  'n_estimators': 150,
#  'num_leaves': 24,
#  'objective': 'regression_l2',
#  'random_state': 20,
#  'reg_alpha': 1,
#  'reg_lambda': 1.4,
#  'subsample': 0.7}

# %%
params = {'task': 'train',
 'learning_rate': 0.16,
 'max_bin': 500,
 'max_depth': 5,
 'n_estimators': 150,
 'num_leaves': 236,
 'objective': 'regression_l2',
 'random_state': 20,
 'reg_alpha': 1,
 'reg_lambda': 1.4,
 'subsample': 0.8}

# %%
import lightgbm as lgb

def lgb_f1_score(y_hat, data):
    y_true = data.get_label()
    y_hat = np.round(y_hat)
    return 'f1', f1_score(y_true, y_hat), True

evals_result = {}

dts_train = lgb.Dataset(dt_train[features], label=dt_train[target])
dts_test = lgb.Dataset(dt_test[features], label=dt_test[target])

model = lgb.train(params,
                  dts_train,
                  valid_sets=[dts_test, dts_train],
                  valid_names=['val', 'train'],
                  feval=lgb_f1_score,
                  evals_result=evals_result,
                  num_boost_round=1000,
                  early_stopping_rounds=1000,
                  verbose_eval=4)
# Out:
# Training until validation scores don't improve for 1000 rounds.
# [4]	train's l2: 0.0836596	train's f1: 0.855563	val's l2: 0.0847231	val's f1: 0.853751
# [8]	train's l2: 0.0545885	train's f1: 0.87605	val's l2: 0.055632	val's f1: 0.874204
# [12]	train's l2: 0.0466888	train's f1: 0.881551	val's l2: 0.048075	val's f1: 0.878967
# [16]	train's l2: 0.0442579	train's f1: 0.884606	val's l2: 0.046024	val's f1: 0.880573
# [20]	train's l2: 0.0432205	train's f1: 0.886454	val's l2: 0.0453072	val's f1: 0.88161
# [24]	train's l2: 0.0426253	train's f1: 0.888	val's l2: 0.0450643	val's f1: 0.882487
# [28]	train's l2: 0.0421144	train's f1: 0.889624	val's l2: 0.0449473	val's f1: 0.8826
# [32]	train's l2: 0.0417246	train's f1: 0.890261	val's l2: 0.044825	val's f1: 0.883741
# [36]	train's l2: 0.0414149	train's f1: 0.890779	val's l2: 0.0447844	val's f1: 0.884282
# [40]	train's l2: 0.041103	train's f1: 0.891853	val's l2: 0.0447561	val's f1: 0.884081
# [44]	train's l2: 0.0408035	train's f1: 0.89273	val's l2: 0.0447043	val's f1: 0.884443
# [48]	train's l2: 0.0405028	train's f1: 0.893372	val's l2: 0.0446689	val's f1: 0.883856
# [52]	train's l2: 0.0402574	train's f1: 0.894049	val's l2: 0.0446771	val's f1: 0.883968
# [56]	train's l2: 0.0399898	train's f1: 0.89458	val's l2: 0.0446047	val's f1: 0.883968
# [60]	train's l2: 0.0397122	train's f1: 0.895323	val's l2: 0.0445573	val's f1: 0.884569
# [64]	train's l2: 0.039445	train's f1: 0.896232	val's l2: 0.0445954	val's f1: 0.883688
# [68]	train's l2: 0.0392314	train's f1: 0.897052	val's l2: 0.0445999	val's f1: 0.883876
# [72]	train's l2: 0.0390228	train's f1: 0.897719	val's l2: 0.0446081	val's f1: 0.883876
# [76]	train's l2: 0.0388235	train's f1: 0.898037	val's l2: 0.0445502	val's f1: 0.884473
# [80]	train's l2: 0.0386524	train's f1: 0.898431	val's l2: 0.0445331	val's f1: 0.884203
# [84]	train's l2: 0.038504	train's f1: 0.898626	val's l2: 0.0445079	val's f1: 0.884266
# [88]	train's l2: 0.038301	train's f1: 0.899162	val's l2: 0.0445147	val's f1: 0.884364
# [92]	train's l2: 0.0381108	train's f1: 0.899624	val's l2: 0.0444967	val's f1: 0.88449
# [96]	train's l2: 0.0378715	train's f1: 0.900084	val's l2: 0.0444747	val's f1: 0.884384
# [100]	train's l2: 0.0377055	train's f1: 0.900494	val's l2: 0.0445029	val's f1: 0.884446
# [104]	train's l2: 0.0375011	train's f1: 0.90129	val's l2: 0.0445124	val's f1: 0.884637
# [108]	train's l2: 0.0373106	train's f1: 0.90133	val's l2: 0.0445399	val's f1: 0.884634
# [112]	train's l2: 0.0371125	train's f1: 0.902335	val's l2: 0.0445183	val's f1: 0.885079
# [116]	train's l2: 0.0368825	train's f1: 0.902643	val's l2: 0.0445008	val's f1: 0.885441
# [120]	train's l2: 0.0367442	train's f1: 0.902845	val's l2: 0.0445058	val's f1: 0.885457
# [124]	train's l2: 0.0365575	train's f1: 0.903489	val's l2: 0.0444888	val's f1: 0.885615
# [128]	train's l2: 0.036379	train's f1: 0.903792	val's l2: 0.0444983	val's f1: 0.885648
# [132]	train's l2: 0.036205	train's f1: 0.904432	val's l2: 0.044509	val's f1: 0.885615
# [136]	train's l2: 0.0360305	train's f1: 0.905068	val's l2: 0.0444841	val's f1: 0.885836
# [140]	train's l2: 0.035852	train's f1: 0.905502	val's l2: 0.0444965	val's f1: 0.885457
# [144]	train's l2: 0.0357131	train's f1: 0.905756	val's l2: 0.0445001	val's f1: 0.885253
# [148]	train's l2: 0.0355538	train's f1: 0.906231	val's l2: 0.0444919	val's f1: 0.884986
# Did not meet early stopping. Best iteration is:
# [150]	train's l2: 0.0354427	train's f1: 0.906809	val's l2: 0.0444945	val's f1: 0.884795

# %%
lgb.plot_metric(evals_result, 'f1')

# %%
from sklearn.pipeline import make_pipeline
from sklearn.metrics import f1_score, r2_score, accuracy_score

pipeline = make_pipeline(LGBMClassifier(**params))

pipeline.fit(dt_train[features], dt_train[target])
predicted = pipeline.predict(dt_test[features])

f1_score(dt_test[target], predicted)
# Out:
# 0.8847952387700155

# %% [markdown]
# ## Submission

# %%
data_test = test[test.x_exit.isnull()].copy()
data_test = data_test.fillna(value=0.0)

# %%
data_test.shape
# Out:
# (33515, 185)

# %%
pipeline.fit(data_train[features], data_train[target])
yhat = pipeline.predict(data_test[features])

# %%
pd.Series(yhat).value_counts()
# Out:
# 0    25203
# 1     8312
# dtype: int64

# %%
submission = pd.DataFrame(list(zip(data_test.trajectory_id, yhat)), columns=['id', 'target'])

# %%
submission.to_csv('../data/submission34.csv', index=False)

# %% [markdown]
# ## Saving data

# %%
data.to_csv('../data/preprocessed/data_preprocessed.csv', sep=',', index=False)

# %%
data.to_hdf('../data/preprocessed/data_preprocessed.hdf', key='data', mode='w')
